# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
#Your code here
df.rename(str.lower, axis='columns')
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# ...

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
#Your code here
df.set_index(df['LINENAME'])
# Out:
#             C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# LINENAME
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# NQR456W    A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# ...

# %% [markdown]
# ## Change the index back

# %%
# Your code here
df.reset_index()
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Your code here
num_lines = []
for line in df['LINENAME']:
    num_lines.append(len(line))

df['Num_Lines'] = num_lines
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# ...

# %% [markdown]
# ## Write a function to clean a column name

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               ',
#        'Num_Lines'],
#       dtype='object')

# %%
def clean(col_name):
    cleaned = col_name.title()
    return cleaned

# %%
# This is a list comprehension. It applies your clean function to every item in the list.
# We then reassign that to df.columns
# You shouldn't have to change anything here.
# Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
# Checking the output, we can see the results.
df.head()
# Out:
#     C/A  Unit       Scp Station Linename Division        Date      Time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# ...

# %% [markdown]
# ## Group the Data by Day of Week and Plot the Sum of The Numeric Columns

# %%
from datetime import datetime
import numpy as np

# %%
# Your code here
temp = pd.to_datetime(df['Date'])
#temp2 = pd.datetime.strptime(df['Date'])

# %%
temp2 = []
for date_listing in temp:
    temp2.append(datetime.date(date_listing).weekday())

# %%
df['int_day_of_week'] = temp2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 13 columns):
# C/A                                                                     197625 non-null object
# Unit                                                                    197625 non-null object
# Scp                                                                     197625 non-null object
# Station                                                                 197625 non-null object
# Linename                                                                197625 non-null object
# Division                                                                197625 non-null object
# Date                                                                    197625 non-null object
# Time                                                                    197625 non-null object
# Desc                                                                    197625 non-null object
# ...

# %%
df['int_day_of_week']
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# 5         5
# 6         6
# 7         6
# 8         6
# 9         6
# 10        6
# 11        6
# 12        0
# 13        0
# 14        0
# 15        0
# 16        0
# 17        0
# 18        1
# 19        1
# 20        1
# 21        1
# 22        1
# 23        1
# 24        2
# 25        2
# 26        2
# 27        2
# 28        2
# 29        2
#          ..
# 197595    0
# 197596    0
# 197597    0
# 197598    0
# 197599    0
# 197600    0
# 197601    1
# 197602    1
# 197603    1
# 197604    1
# 197605    1
# 197606    1
# 197607    2
# 197608    2
# 197609    2
# 197610    2
# 197611    2
# 197612    2
# 197613    3
# 197614    3
# 197615    3
# 197616    3
# 197617    3
# 197618    3
# 197619    4
# 197620    4
# 197621    4
# 197622    4
# 197623    4
# 197624    4
# Name: int_day_of_week, Length: 197625, dtype: int64

# %%
df['is_weekday'] = np.isin(df['int_day_of_week'], [0,1,2,3,4])

# %% [markdown]
# ## Group the Data by Weekend/Weekday and Plot the Sum of the Numeric Columns

# %%
df['int_day_of_week']
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# 5         5
# 6         6
# 7         6
# 8         6
# 9         6
# 10        6
# 11        6
# 12        0
# 13        0
# 14        0
# 15        0
# 16        0
# 17        0
# 18        1
# 19        1
# 20        1
# 21        1
# 22        1
# 23        1
# 24        2
# 25        2
# 26        2
# 27        2
# 28        2
# 29        2
#          ..
# 197595    0
# 197596    0
# 197597    0
# 197598    0
# 197599    0
# 197600    0
# 197601    1
# 197602    1
# 197603    1
# 197604    1
# 197605    1
# 197606    1
# 197607    2
# 197608    2
# 197609    2
# 197610    2
# 197611    2
# 197612    2
# 197613    3
# 197614    3
# 197615    3
# 197616    3
# 197617    3
# 197618    3
# 197619    4
# 197620    4
# 197621    4
# 197622    4
# 197623    4
# 197624    4
# Name: int_day_of_week, Length: 197625, dtype: int64

# %%
#Your code here
by_weekday = df.groupby(['int_day_of_week'], as_index=True)
by_weekday[:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d8b579739a4a> in <module>()
#       1 #Your code here
#       2 by_weekday = df.groupby(['int_day_of_week'], as_index=True)
# ----> 3 by_weekday[:10]
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     264
#     265         else:
# --> 266             if key not in self.obj:
#     267                 raise KeyError("Column not found: {key}".format(key=key))
#     268             return self._gotitem(key, ndim=1)
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in __contains__(self, key)
#    1520     def __contains__(self, key):
#    1521         """True if the key is in the info axis"""
# -> 1522         return key in self._info_axis
#    1523
#    1524     @property
#
# ...

# %% [markdown]
# ## Analysis Question:
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
